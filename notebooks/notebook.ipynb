# %% [markdown]
# ## Web Scraping

# %%
import sys
from pathlib import Path

# Add repository root (one level up from notebooks/) to sys.path
sys.path.append(str(Path('..').resolve()))

from ingestion.web_scraping_esilv import scrape_esilv_website

# %%
#scrape_esilv_website()
